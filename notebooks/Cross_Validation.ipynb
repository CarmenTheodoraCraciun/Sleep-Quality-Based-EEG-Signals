# %% [markdown]
# # Machine Learning Systems for Sleep Quality Assessment Based on EEG Signals
#
# ---
#
# * **Author**: Carmen-Theodora Craciun
# * **The purpose of this Notebook**: This notebook take our best hiper-tunning/ architecures and apply the Stratified Cross Validation. Make a big dataset from train and val, *apply 5 folds for each model, save accuracies, cohen's kappa scores* and the best variant of the model.
# * **Enviroment**: Jupyter in an Ubuntu VM
# * **Datasets**:
#   * [Sleep-EDFX Database](https://www.physionet.org/content/sleep-edfx/1.0.0/) - channel EEG Fpz-Cz
#   * [University College Dublin Sleep Apnea Database](https://physionet.org/content/ucddb/1.0.0/) - channel EEG C3-A2
#   * [Haaglanden Medisch Centrum sleep staging database (PhysioNet)](https://physionet.org/content/hmc-sleep-staging/1.1/recordings/#files-panel) - channel EEG C4-M1
#   * **Files used in this Notebook**: `utils.py`
# * **Output**:
#   * Generate a `model_results.csv` file with the statistic data
#     * Columns: full_name,name,type,acc_mean,acc_std,kappa_mean,kappa_std,acc_best,kappa_best,fold_accs,fold_kappas,path
#   * The models save in formats: `.pkl` (Tree-Based and Probabilistic Models) and `.keras` (Deep Learning and Hybrid)
# * **Files used in this Notebook**: `utils.py`

# %% [markdown]
# # Imports

# %%
import os
import warnings

warnings.filterwarnings("ignore")
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.metrics import accuracy_score, cohen_kappa_score
from sklearn.model_selection import StratifiedGroupKFold, GroupKFold
import numpy as np
import joblib
from sklearn.base import clone
from tensorflow.keras import layers, models
from sklearn.calibration import CalibratedClassifierCV
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
import lightgbm as lgb
import tensorflow as tf
import gc
import shutil
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Dropout, Input, GlobalAveragePooling1D
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from scipy.ndimage import gaussian_filter1d

# %%
train_path_csv = 'process_dataset/extracted_features/train_features.csv'
val_path_csv = 'process_dataset/extracted_features/val_features.csv'

train_path = "process_dataset/train"
val_path   = "process_dataset/val"

class_distribution_path = 'process_dataset/class_distribution_train.csv'

results = []

# %%
import utils

# %% [markdown]
# # Cross Validation

# %% [markdown]
# ## ML

# %%
def cross_validation(
    model, X, y, subjects,
    model_name, model_type, save_path='./models',
    n_splits=5, sample_weights=None,
    to_calibrate=False
):
    '''Cross-validate for LightGBM, XGBoost, Random Forest, LDA and Logistic Regression.'''
    print(f"=== Cross Validation for {model_name} ({n_splits} folds) ===")

    X_arr = np.array(X)
    y_arr = np.array(y)
    subjects_arr = np.array(subjects)

    cv = StratifiedGroupKFold(n_splits=n_splits, shuffle=True, random_state=42)

    fold_accuracies = []
    fold_kappas = []

    best_acc = 0.0
    best_model = None

    if not os.path.exists(save_path):
        os.makedirs(save_path)

    for fold, (train_idx, val_idx) in enumerate(cv.split(X_arr, y_arr, groups=subjects_arr), 1):
        print(f"===== FOLD {fold}/{n_splits} =====")
        
        X_train, X_val = X_arr[train_idx], X_arr[val_idx]
        y_train, y_val = y_arr[train_idx], y_arr[val_idx]

        cloned_model = clone(model)

        # Train base model
        if sample_weights is None:
            cloned_model.fit(X_train, y_train)
        else:
            cloned_model.fit(X_train, y_train, sample_weight=sample_weights[train_idx])

        # Optional calibration
        if to_calibrate:
            calibrated_model = CalibratedClassifierCV(
                estimator=cloned_model,
                method='sigmoid',
                cv=5
            )
            calibrated_model.fit(X_train, y_train)
            model_to_eval = calibrated_model
        else:
            model_to_eval = cloned_model

        # Predict on validation
        y_pred = model_to_eval.predict(X_val)

        acc = accuracy_score(y_val, y_pred)
        kappa = cohen_kappa_score(y_val, y_pred)

        fold_accuracies.append(acc)
        fold_kappas.append(kappa)

        msg = f"Accuracy = {acc:.4f}, Kappa = {kappa:.4f}"

        # Save best model
        if acc > best_acc:
            best_acc = acc
            best_model = model_to_eval
            msg += " -> Best model"

        print(msg)
        print()
            

    best_model_path = os.path.join(save_path, f"best_{model_name}.pkl")
    joblib.dump(best_model, best_model_path)

    print("\n===== FINAL RESULTS =====")
    mean_acc = np.mean(fold_accuracies)
    std_acc = np.std(fold_accuracies)
    mean_kappa = np.mean(fold_kappas)
    std_kappa = np.std(fold_kappas)
    
    print(f"Mean ACC:   {mean_acc:.4f}")
    print(f"Mean KAPPA: {mean_kappa:.4f}")
    print(f"Best model saved at: {best_model_path}")
    
    return {
        "name": model_name,
        "type": model_type,
        "acc_mean": float(mean_acc),
        "acc_std": float(std_acc),
        "kappa_mean": float(mean_kappa),
        "kappa_std": float(std_kappa),
        "acc_best": float(max(fold_accuracies)),
        "kappa_best": float(max(fold_kappas)),
        "fold_accs": fold_accuracies,
        "fold_kappas": fold_kappas,
        "path": best_model_path
    }

# %% [markdown]
# ## DL on extracted

# %%
def cross_validate_keras_model(
    X,y,subjects,build_model_fn,
    model_name,full,model_type,n_splits=5,
    batch_size=32,epochs=50,
    callbacks_list=None,
    verbose=1,save_path="best_models"
):
    '''Cross-validate for MLP, LSTM and ResNet.'''
    os.makedirs(save_path, exist_ok=True)

    X = np.array(X)
    y = np.array(y)
    subjects = np.array(subjects)

    cv = StratifiedGroupKFold(n_splits=n_splits, shuffle=True, random_state=42)

    fold_accuracies = []
    fold_kappas = []
    best_acc = -1
    best_kappa = 0
    best_model_path = None

    for fold, (train_idx, val_idx) in enumerate(cv.split(X, y, groups=subjects), 1):
        print(f"===== FOLD {fold}/{n_splits} =====")
    
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]
        
        # One-hot ONLY for LSTM (focal loss)
        if "lstm" in model_name.lower():
            num_classes = len(np.unique(y))
            y_train = tf.keras.utils.to_categorical(y_train, num_classes)
            y_val   = tf.keras.utils.to_categorical(y_val, num_classes)
    
        # Detect input shape
        input_shape = X_train.shape[1:]
        num_classes = len(np.unique(y))
    
        # Build model
        model = build_model_fn(input_shape, num_classes)

        # Callbacks
        callbacks = callbacks_list() if callbacks_list is not None else None

        # Train
        model.fit(
            X_train, y_train,
            validation_data=(X_val, y_val),
            epochs=epochs,
            batch_size=batch_size,
            callbacks=callbacks,
            verbose=verbose
        )

        # Predict
        y_pred = np.argmax(model.predict(X_val, verbose=0), axis=1)
        
        # Convert y_val to sparse if one-hot
        if y_val.ndim == 2:
            y_val_sparse = np.argmax(y_val, axis=1)
        else:
            y_val_sparse = y_val
        
        acc = accuracy_score(y_val_sparse, y_pred)
        kappa = cohen_kappa_score(y_val_sparse, y_pred)

        fold_accuracies.append(acc)
        fold_kappas.append(kappa)

        msg = f"Accuracy = {acc:.4f}, Kappa = {kappa:.4f}"

        # Save best model
        if acc > best_acc:
            best_acc = acc
            best_kappa = kappa
            best_model_path = os.path.join(save_path, f"best_{model_name}.keras")
            model.save(best_model_path)
            msg += " -> Best model"

        print(msg)
        print()

        # Cleanup
        del model
        tf.keras.backend.clear_session()
        gc.collect()

    print("\n===== FINAL RESULTS =====")
    mean_acc = np.mean(fold_accuracies)
    std_acc = np.std(fold_accuracies)
    mean_kappa = np.mean(fold_kappas)
    std_kappa = np.std(fold_kappas)
    
    print(f"Mean ACC:   {mean_acc:.4f}")
    print(f"Mean KAPPA: {mean_kappa:.4f}")
    print(f"Best model saved at: {best_model_path}")

    return {
        "name": model_name,
        "type": model_type,
        "acc_mean": float(mean_acc),
        "acc_std": float(std_acc),
        "kappa_mean": float(mean_kappa),
        "kappa_std": float(std_kappa),
        "acc_best": float(best_acc),
        "kappa_best": float(best_kappa),
        "fold_accs": fold_accuracies,
        "fold_kappas": fold_kappas,
        "path": best_model_path
    }

# %% [markdown]
# ## CNN

# %%
def kfold_cnn_generators_grouped(
    X_paths,y,subjects,
    build_model_fn,
    model_name,model_type,
    generator_fn,batch_size,
    callbacks_fn = None,
    epochs=40,n_splits=5,
    save_path="best_models",
    verbose=1
):
    '''Cross-validate for CNN.'''
    os.makedirs(save_path, exist_ok=True)

    cv = GroupKFold(n_splits=n_splits, shuffle=True, random_state=42)

    fold_accuracies = []
    fold_kappas = []
    best_acc = -1
    best_model_path = None

    for fold, (train_idx, val_idx) in enumerate(cv.split(X_paths, y, groups=subjects), 1):
        print(f"===== FOLD {fold}/{n_splits} =====")

        fold_train_dir = f"fold_train_{fold}"
        fold_val_dir   = f"fold_val_{fold}"

        os.makedirs(fold_train_dir, exist_ok=True)
        os.makedirs(fold_val_dir, exist_ok=True)

        for idx in train_idx:
            shutil.copy(X_paths[idx], fold_train_dir)

        for idx in val_idx:
            shutil.copy(X_paths[idx], fold_val_dir)

        train_gen = generator_fn(fold_train_dir, True, batch_size)
        val_gen   = generator_fn(fold_val_dir, False, batch_size)

        # Model
        sample_batch, _ = train_gen[0]
        input_shape = sample_batch.shape[1:]

        model = build_model_fn(input_shape=input_shape)

        if callbacks_fn is None:
            callbacks = []
        else: callbacks = callbacks_fn()

        # Train
        model.fit(
            train_gen,
            validation_data=val_gen,
            epochs=epochs,
            callbacks=callbacks,
            verbose=verbose
        )

        # Evaluate
        y_true = []
        y_pred = []

        for Xb, yb in val_gen:
            y_true.extend(np.argmax(yb, axis=1))
            y_pred.extend(np.argmax(model.predict(Xb, verbose=0), axis=1))

        y_true = np.array(y_true)
        y_pred = np.array(y_pred)

        acc = accuracy_score(y_true, y_pred)
        kappa = cohen_kappa_score(y_true, y_pred)

        fold_accuracies.append(acc)
        fold_kappas.append(kappa)
                
        msg = f"Accuracy = {acc:.4f}, Kappa = {kappa:.4f}"

        # 7. Salvăm cel mai bun model
        if acc > best_acc:
            best_acc = acc
            best_model_path = os.path.join(save_path, f"best_{model_name}.keras")
            model.save(best_model_path)
            msg += " -> Best model"

        print(msg)
        print()

        # Clean the memory
        del model, train_gen, val_gen
        tf.keras.backend.clear_session()
        gc.collect()

        shutil.rmtree(fold_train_dir)
        shutil.rmtree(fold_val_dir)


    print("\n===== FINAL RESULTS =====")
    mean_acc = np.mean(fold_accuracies)
    std_acc = np.std(fold_accuracies)
    mean_kappa = np.mean(fold_kappas)
    std_kappa = np.std(fold_kappas)
    
    print(f"Mean ACC:   {mean_acc:.4f}")
    print(f"Mean KAPPA: {mean_kappa:.4f}")
    print(f"Best model saved at: {best_model_path}")

    return {
        "name": model_name,
        "type": model_type,
        "acc_mean": float(mean_acc),
        "acc_std": float(std_acc),
        "kappa_mean": float(mean_kappa),
        "kappa_std": float(std_kappa),
        "acc_best": float(best_acc),
        "kappa_best": float(max(fold_kappas)),
        "fold_accs": fold_accuracies,
        "fold_kappas": fold_kappas,
        "path": best_model_path
    }

# %% [markdown]
# ## SeqSleepNet

# %%
def crossval_seqsleepnet(
    X_paths,y,subjects,
    build_model_fn,
    model_name,model_type,
    generator_fn,
    batch_size = 32,
    epochs=40,n_splits=5,
    save_path="best_models",
    verbose=1
):
    os.makedirs(save_path, exist_ok=True)

    cv = GroupKFold(n_splits=n_splits)

    fold_accuracies = []
    fold_kappas = []
    best_acc = -1
    best_model_path = None

    for fold, (train_idx, val_idx) in enumerate(cv.split(X_paths, y, groups=subjects), 1):
        print(f"===== FOLD {fold}/{n_splits} =====")

        # Create fold directories
        fold_train = f"fold_train_{fold}"
        fold_val   = f"fold_val_{fold}"
        os.makedirs(fold_train, exist_ok=True)
        os.makedirs(fold_val, exist_ok=True)

        for idx in train_idx:
            shutil.copy(X_paths[idx], fold_train)
        for idx in val_idx:
            shutil.copy(X_paths[idx], fold_val)

        # Generators
        train_gen = generator_fn(fold_train, True, batch_size)
        val_gen   = generator_fn(fold_val, False, batch_size)

        # Build + compile model
        model = build_model_fn()
        model.compile(
            optimizer=tf.keras.optimizers.Adam(1e-3),
            loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
            metrics=["accuracy"]
        )

        es = tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=7,
            restore_best_weights=True,
            verbose=1
        )

        lr = tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=3,
            min_lr=1e-6,
            verbose=1
        )

        model.fit(
            train_gen,
            validation_data=val_gen,
            epochs=epochs,
            callbacks=[es, lr],
            verbose=verbose
        )

        y_true = []
        for _, yb in val_gen:
            y_true.extend(np.argmax(yb, axis=1))
        y_true = np.array(y_true)

        # Raw predictions
        y_pred_proba = model.predict(val_gen, verbose=0)

        # Smooting 
        sigma_list = [0.5, 1.0, 1.5]
        probas_smooth = [
            gaussian_filter1d(y_pred_proba, sigma=s, axis=0, mode="nearest")
            for s in sigma_list
        ]
        proba_smooth = np.mean(probas_smooth, axis=0)

        temps = [0.85, 0.45, 0.75, 0.95, 0.75]
        A = utils.compute_transition_matrix_adaptive(y_true, temps)
        y_hmm = utils.viterbi(proba_smooth, A)

        y_med = utils.adaptive_median(y_hmm)
        y_final = utils.physiologic_rules(y_med)

        # Metrics
        acc = np.mean(y_final == y_true)
        kappa = cohen_kappa_score(y_true, y_final)

        fold_accuracies.append(acc)
        fold_kappas.append(kappa)

        msg = f"Fold ACC={acc:.4f}, Kappa={kappa:.4f}"

        if acc > best_acc:
            best_acc = acc
            best_model_path = os.path.join(save_path, f"best_{model_name}.keras")
            model.save(best_model_path)
            msg += "  <-- BEST"

        print(msg)

        # Cleanup
        del model, train_gen, val_gen
        tf.keras.backend.clear_session()
        gc.collect()
        shutil.rmtree(fold_train)
        shutil.rmtree(fold_val)
        print()

    print("\n===== FINAL RESULTS =====")
    mean_acc = np.mean(fold_accuracies)
    std_acc = np.std(fold_accuracies)
    mean_kappa = np.mean(fold_kappas)
    std_kappa = np.std(fold_kappas)
    
    print(f"Mean ACC:   {mean_acc:.4f}")
    print(f"Mean KAPPA: {mean_kappa:.4f}")
    print(f"Best model saved at: {best_model_path}")

    return {
        "name": model_name,
        "type": model_type,
        "acc_mean": float(mean_acc),
        "acc_std": float(std_acc),
        "kappa_mean": float(mean_kappa),
        "kappa_std": float(std_kappa),
        "acc_best": float(best_acc),
        "kappa_best": float(max(fold_kappas)),
        "accs": fold_accuracies,
        "kappas": fold_kappas,
        "file_name": f"best_{model_name}.keras"
    }

# %% [markdown]
# # Dataset

# %%
df_train = pd.read_csv(train_path_csv)
df_val = pd.read_csv(val_path_csv)

df_total = pd.concat([df_train, df_val], axis=0)
subjects = df_total['Subject_ID'].values

cols_to_drop = ['Subject_ID', 'Dataset_Source', 'Label']
feature_cols = [c for c in df_total.columns if c not in cols_to_drop]

X_total = df_total[feature_cols]
y_total = df_total['Label']

class_distribution = pd.read_csv(class_distribution_path)

class_weights = dict(zip(class_distribution['Class_ID'], class_distribution['Weight']))

sample_weights_custom = np.array([class_weights[y] for y in y_total])

# %%
def get_file_list_from_folders(*folders):
    file_list = []
    for folder in folders:
        for f in os.listdir(folder):
            if f.endswith(".npz"):
                file_list.append(os.path.join(folder, f))
    return np.array(file_list)

def create_generator(directory, is_training, batch_size):
    return utils.SleepDataGenerator(
        directory=directory,
        is_training=is_training,
        batch_size=batch_size,
        n_classes=5,
        use_context=True,
        window_size=3,
        use_lag_lead=True,
        downsample=True,
        target_length=1500,
        sampling_rate=50,
        lag_seconds=0.5
    )

def extract_subjects(file_list):
    subjects = []
    for f in file_list:
        fname = os.path.basename(f)
        digits = ''.join([c for c in fname if c.isdigit()])
        subjects.append(int(digits[:2]))
    return np.array(subjects)

def extract_labels(file_list):
    labels = []
    for f in file_list:
        data = np.load(f, allow_pickle=True)

        y_raw = data["y"] if "y" in data else data["arr_1"]
        y_raw = np.array(y_raw).reshape(-1)
        label = int(np.bincount(y_raw).argmax())

        labels.append(label)

    return np.array(labels)

file_list = get_file_list_from_folders(train_path, val_path)
labels = extract_labels(file_list)
subjects = extract_subjects(file_list)

# %% [markdown]
# # Models Cross Validation

# %% [markdown]
# ## LightGBM

# %%
lgb_model = lgb.LGBMClassifier(
    n_estimators=400,
    learning_rate=0.08,
    max_depth=10,
    num_leaves=125,
    random_state=42,
    n_jobs=-1,
    verbose=-1
)

results.append(cross_validation(
    model=lgb_model,
    X=X_total,
    y=y_total,
    subjects=subjects,
    model_name="LGBM_calibrated",
    model_type='Tree-Based',
    sample_weights=sample_weights_custom,
    save_path="./models",
    to_calibrate=True
))
# Out:
# === Cross Validation for LGBM_calibrated (5 folds) ===
# ===== FOLD 1/5 =====
# Accuracy = 0.7822, Kappa = 0.7029 -> Best model
#
# ===== FOLD 2/5 =====
# Accuracy = 0.7666, Kappa = 0.6816
#
# ===== FOLD 3/5 =====
# Accuracy = 0.7568, Kappa = 0.6683
#
# ===== FOLD 4/5 =====
# Accuracy = 0.7642, Kappa = 0.6797
#
# ===== FOLD 5/5 =====
# Accuracy = 0.7858, Kappa = 0.7113 -> Best model
#
#
# ===== FINAL RESULTS =====
# Mean ACC:   0.7711
# Mean KAPPA: 0.6888
# Best model saved at: ./models/best_LGBM_calibrated.pkl

# %% [markdown]
# ## XGBoost

# %%
xgb_model = xgb.XGBClassifier(
    objective='multi:softprob',
    num_class=5,
    eval_metric='mlogloss',
    random_state=42,
    n_estimators=400,
    learning_rate=0.08,
    max_depth=8,
    subsample=0.8,
    colsample_bytree=0.8,
    tree_method='hist',
    enable_categorical=True,
    n_jobs=-1
)

results.append(cross_validation(
    model=xgb_model,
    X=X_total,
    y=y_total,
    subjects=subjects,
    model_name="XGB_calibrated",
    model_type='Tree-Based',
    sample_weights=sample_weights_custom,
    save_path="./models",
    to_calibrate=True
))
# Out:
# === Cross Validation for XGB_calibrated (5 folds) ===
# ===== FOLD 1/5 =====
# Accuracy = 0.7802, Kappa = 0.7003 -> Best model
#
# ===== FOLD 2/5 =====
# Accuracy = 0.7679, Kappa = 0.6838
#
# ===== FOLD 3/5 =====
# Accuracy = 0.7565, Kappa = 0.6681
#
# ===== FOLD 4/5 =====
# Accuracy = 0.7636, Kappa = 0.6793
#
# ===== FOLD 5/5 =====
# Accuracy = 0.7836, Kappa = 0.7086 -> Best model
#
#
# ===== FINAL RESULTS =====
# Mean ACC:   0.7704
# Mean KAPPA: 0.6880
# Best model saved at: ./models/best_XGB_calibrated.pkl

# %% [markdown]
# ## Random Forest

# %%
rf_model = RandomForestClassifier(
    n_estimators=100,
    max_depth=None,
    min_samples_split=5,
    min_samples_leaf=2,
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)

results.append(cross_validation(
    model=rf_model,
    X=X_total,
    y=y_total,
    subjects=subjects,
    model_name="RF_calibrated",
    model_type='Tree-Based',
    sample_weights=sample_weights_custom,
    save_path="./models",
    to_calibrate=True
))
# Out:
# === Cross Validation for RF_calibrated (5 folds) ===
# ===== FOLD 1/5 =====
# Accuracy = 0.7524, Kappa = 0.6625 -> Best model
#
# ===== FOLD 2/5 =====
# Accuracy = 0.7389, Kappa = 0.6433
#
# ===== FOLD 3/5 =====
# Accuracy = 0.7308, Kappa = 0.6330
#
# ===== FOLD 4/5 =====
# Accuracy = 0.7340, Kappa = 0.6386
#
# ===== FOLD 5/5 =====
# Accuracy = 0.7602, Kappa = 0.6763 -> Best model
#
#
# ===== FINAL RESULTS =====
# Mean ACC:   0.7433
# Mean KAPPA: 0.6507
# Best model saved at: ./models/best_RF_calibrated.pkl

# %% [markdown]
# ## LDA

# %%
lda_lsqr = LinearDiscriminantAnalysis(solver='lsqr', shrinkage='auto')

results.append(cross_validation(
    model=lda_lsqr,
    X=X_total,
    y=y_total,
    subjects=subjects,
    model_name="LDA-Baseline",
    model_type='Probabilistic',
    save_path="./models"
))
# Out:
# === Cross Validation for LDA-Baseline (5 folds) ===
# ===== FOLD 1/5 =====
# Accuracy = 0.7391, Kappa = 0.6459 -> Best model
#
# ===== FOLD 2/5 =====
# Accuracy = 0.7234, Kappa = 0.6239
#
# ===== FOLD 3/5 =====
# Accuracy = 0.7122, Kappa = 0.6098
#
# ===== FOLD 4/5 =====
# Accuracy = 0.7134, Kappa = 0.6116
#
# ===== FOLD 5/5 =====
# Accuracy = 0.7377, Kappa = 0.6467
#
#
# ===== FINAL RESULTS =====
# Mean ACC:   0.7251
# Mean KAPPA: 0.6276
# Best model saved at: ./models/best_LDA-Baseline.pkl

# %% [markdown]
# ## Logistic Regression

# %%
lr_lbfgs = LogisticRegression(
    class_weight='balanced',
    max_iter=5000,
    C=0.5,
    solver='lbfgs',
    random_state=42
)

results.append(cross_validation(
    model=lr_lbfgs,
    X=X_total,
    y=y_total,
    subjects=subjects,
    model_name="LogisticR-Baseline",
    model_type='Probabilistic',
    save_path="./models"
))
# Out:
# === Cross Validation for LogisticR-Baseline (5 folds) ===
# ===== FOLD 1/5 =====
# Accuracy = 0.7299, Kappa = 0.6477 -> Best model
#
# ===== FOLD 2/5 =====
# Accuracy = 0.7033, Kappa = 0.6137
#
# ===== FOLD 3/5 =====
# Accuracy = 0.6939, Kappa = 0.6031
#
# ===== FOLD 4/5 =====
# Accuracy = 0.7116, Kappa = 0.6239
#
# ===== FOLD 5/5 =====
# Accuracy = 0.7218, Kappa = 0.6407
#
#
# ===== FINAL RESULTS =====
# Mean ACC:   0.7121
# Mean KAPPA: 0.6258
# Best model saved at: ./models/best_LogisticR-Baseline.pkl

# %% [markdown]
# ## MLP

# %%
def build_mlp(input_shape, n_classes, dropout_rate=0.3):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Dense(256, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(dropout_rate),
        layers.Dense(128, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(dropout_rate),
        layers.Dense(64, activation='relu'),
        layers.Dense(n_classes, activation='softmax')
    ])
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

results.append(cross_validate_keras_model(
    X=X_total,
    y=y_total,
    subjects=subjects,
    build_model_fn=build_mlp,
    model_name="MLP",
    model_type='DL',
    batch_size=32,
    epochs=50,
    callbacks_list=utils.make_callbacks,
    save_path="./models"
))
# Out:
# ===== FOLD 1/5 =====
# Epoch 1/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - accuracy: 0.7161 - loss: 0.7450 - val_accuracy: 0.7571 - val_loss: 0.6423 - learning_rate: 0.0010
# Epoch 2/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - accuracy: 0.7453 - loss: 0.6670 - val_accuracy: 0.7686 - val_loss: 0.6150 - learning_rate: 0.0010
# Epoch 3/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - accuracy: 0.
50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - accuracy: 0.8055 - loss: 0.5005 - val_accuracy: 0.7891 - val_loss: 0.5484 - learning_rate: 2.5000e-04
# Epoch 34/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - accuracy: 0.8060 - loss: 0.4987 - val_accuracy: 0.7889 - val_loss: 0.5496 - learning_rate: 2.5000e-04
# Epoch 35/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - accuracy: 0.8063 - loss: 0.4970 - val_accuracy: 0.7891 - val_loss: 0.5524 - learning_rate: 2.5000e-04
# Epoch 36/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - accuracy: 0.8074 - loss: 0.4935 - val_accuracy: 0.7901 - val_loss: 0.5498 - learning_rate: 1.2500e-04
# Epoch 37/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - accuracy: 0.8085 - loss: 0.4917 - val_accuracy: 0.7889 - val_loss: 0.5504 - learning_rate: 1.2500e-04
# Epoch 38/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - accuracy: 0.8079 - loss: 0.4916 - val_accuracy: 0.7893 - val_loss: 0.5496 - learning_rate: 1.2500e-04
# Epoch 39/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - accuracy: 0.8082 - loss: 0.4899 - val_accuracy: 0.7890 - val_loss: 0.5524 - learning_rate: 1.2500e-04
# Epoch 40/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - accuracy: 0.8098 - loss: 0.4882 - val_accuracy: 0.7899 - val_loss: 0.5503 - learning_rate: 1.2500e-04
# Accuracy = 0.7918, Kappa = 0.7205 -> Best model
#
#
# ===== FINAL RESULTS =====
# Mean ACC:   0.7764
# Mean KAPPA: 0.6990
# Best model saved at: ./models/best_mlp.keras

# %% [markdown]
# ## LSTM

# %%
def build_lstm_se_focal(input_shape, n_classes, units=128, dropout=0.4, recurrent_dropout=0.2):
    inputs = layers.Input(shape=input_shape)

    # LSTM 1 (return sequences)
    x = layers.LSTM(
        units,
        return_sequences=True,
        dropout=dropout,
        recurrent_dropout=recurrent_dropout
    )(inputs)
    x = layers.BatchNormalization()(x)

    # LSTM 2 (return last hidden state)
    x = layers.LSTM(
        units // 2,
        dropout=dropout,
        recurrent_dropout=recurrent_dropout
    )(x)
    x = layers.BatchNormalization()(x)

    # SE block
    x = utils.se_feature_attention(x)

    # Dense layers
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(64, activation='relu', kernel_regularizer='l2')(x)
    x = layers.Dropout(0.2)(x)

    outputs = layers.Dense(n_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss=utils.categorical_focal_loss(gamma=2.0, alpha=0.25),
        metrics=['accuracy']
    )
    return model

results.append(cross_validate_keras_model(
    X=X_total,
    y=y_total,
    subjects=subjects,
    build_model_fn=build_lstm_se_focal,
    model_name="lstm_se_focal",
    model_type='DL',
    batch_size=32,
    epochs=50,
    callbacks_list=utils.make_callbacks,
    save_path="./models"
))
# Out:
# ===== FOLD 1/5 =====
# Epoch 1/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 69s 9ms/step - accuracy: 0.6875 - loss: 0.1163 - val_accuracy: 0.7342 - val_loss: 0.0863 - learning_rate: 0.0010
# Epoch 2/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 62s 9ms/step - accuracy: 0.7142 - loss: 0.0946 - val_accuracy: 0.7454 - val_loss: 0.0834 - learning_rate: 0.0010
# Epoch 3/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 63s 9ms/step - accuracy: 0.7200 - loss: 0.0916 - val_accuracy: 0.7448 - val_loss: 0.0808 - learning_rate: 0.0010
# Epoch 4/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 61s 9ms/step - accuracy: 0.7235 - loss: 0.0901 - val_accuracy: 0.7488 - val_loss: 0.0799 - learning_rate: 0.0010
# Epoch 5/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 63s 9ms/step - accuracy: 0.7263 - loss: 0.0886 - val_accuracy: 0.7563 - val_loss: 0.0785 - learning_rate: 0.0010
# Epoch 6/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 63s 9ms/step - accuracy: 0.
50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 52s 7ms/step - accuracy: 0.7512 - loss: 0.0734 - val_accuracy: 0.7656 - val_loss: 0.0708 - learning_rate: 2.5000e-04
# Epoch 39/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 49s 7ms/step - accuracy: 0.7496 - loss: 0.0736 - val_accuracy: 0.7617 - val_loss: 0.0698 - learning_rate: 2.5000e-04
# Epoch 40/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 52s 7ms/step - accuracy: 0.7529 - loss: 0.0725 - val_accuracy: 0.7715 - val_loss: 0.0685 - learning_rate: 1.2500e-04
# Epoch 41/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 53s 7ms/step - accuracy: 0.7531 - loss: 0.0719 - val_accuracy: 0.7685 - val_loss: 0.0683 - learning_rate: 1.2500e-04
# Epoch 42/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 54s 8ms/step - accuracy: 0.7524 - loss: 0.0721 - val_accuracy: 0.7717 - val_loss: 0.0687 - learning_rate: 1.2500e-04
# Epoch 43/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 55s 8ms/step - accuracy: 0.7532 - loss: 0.0720 - val_accuracy: 0.7733 - val_loss: 0.0680 - learning_rate: 1.2500e-04
# Epoch 44/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 56s 8ms/step - accuracy: 0.7537 - loss: 0.0719 - val_accuracy: 0.7727 - val_loss: 0.0674 - learning_rate: 1.2500e-04
# Epoch 45/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 57s 8ms/step - accuracy: 0.7522 - loss: 0.0719 - val_accuracy: 0.7685 - val_loss: 0.0687 - learning_rate: 1.2500e-04
# Epoch 46/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 58s 8ms/step - accuracy: 0.7528 - loss: 0.0720 - val_accuracy: 0.7724 - val_loss: 0.0672 - learning_rate: 1.2500e-04
# Epoch 47/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 56s 8ms/step - accuracy: 0.7531 - loss: 0.0716 - val_accuracy: 0.7658 - val_loss: 0.0686 - learning_rate: 1.2500e-04
# Epoch 48/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 59s 8ms/step - accuracy: 0.7542 - loss: 0.0715 - val_accuracy: 0.7682 - val_loss: 0.0685 - learning_rate: 1.2500e-04
# Epoch 49/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 62s 9ms/step - accuracy: 0.7543 - loss: 0.0711 - val_accuracy: 0.7725 - val_loss: 0.0673 - learning_rate: 6.2500e-05
# Epoch 50/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 59s 8ms/step - accuracy: 0.7543 - loss: 0.0710 - val_accuracy: 0.7729 - val_loss: 0.0675 - learning_rate: 6.2500e-05
# Accuracy = 0.7733, Kappa = 0.6968 -> Best model
#
#
# ===== FINAL RESULTS =====
# Mean ACC:   0.7611
# Mean KAPPA: 0.6776
# Best model saved at: ./models/best_lstm_se_focal.keras

# %% [markdown]
# ## ResNet

# %%
def build_resnet_feature_model(seq_len, n_features, n_classes=5):
    inp = layers.Input(shape=(seq_len, n_features))

    def conv_block(x, filters):
        shortcut = x

        x = layers.Conv1D(filters, 3, padding='same',
                          kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)

        x = layers.Conv1D(filters, 3, padding='same',
                          kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
        x = layers.BatchNormalization()(x)

        if shortcut.shape[-1] != filters:
            shortcut = layers.Conv1D(filters, 1, padding='same',
                                     kernel_regularizer=tf.keras.regularizers.l2(1e-4))(shortcut)

        x = layers.Add()([x, shortcut])
        x = layers.ReLU()(x)
        x = layers.Dropout(0.2)(x)
        return x

    x = conv_block(inp, 32)
    x = conv_block(x, 64)
    x = conv_block(x, 128)

    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu',
                     kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
    x = layers.Dropout(0.4)(x)
    out = layers.Dense(n_classes, activation='softmax')(x)

    model = models.Model(inp, out)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(3e-4),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(),
        metrics=['accuracy']
    )
    return model

def build_resnet_wrapper(input_shape,num_classes=5):
    seq_len = input_shape[0]
    n_features = input_shape[1]
    return build_resnet_feature_model(seq_len, n_features, num_classes)

results.append(cross_validate_keras_model(
    X=X_total,
    y=y_total,
    subjects=subjects,
    build_model_fn=build_resnet_wrapper,
    model_name="resnet_feature",
    model_type='DL',
    batch_size=32,
    epochs=50,
    callbacks_list=utils.make_callbacks,
    save_path="./models"
))
# Out:
# ===== FOLD 1/5 =====
# Epoch 1/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 53s 7ms/step - accuracy: 0.6864 - loss: 0.8942 - val_accuracy: 0.7384 - val_loss: 0.7310 - learning_rate: 3.0000e-04
# Epoch 2/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 49s 7ms/step - accuracy: 0.7330 - loss: 0.7588 - val_accuracy: 0.7507 - val_loss: 0.6940 - learning_rate: 3.0000e-04
# Epoch 3/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 47s 7ms/step - accuracy: 0.7452 - loss: 0.7201 - val_accuracy: 0.7598 - val_loss: 0.6729 - learning_rate: 3.0000e-04
# Epoch 4/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 49s 7ms/step - accuracy: 0.7513 - loss: 0.6982 - val_accuracy: 0.7615 - val_loss: 0.6580 - learning_rate: 3.0000e-04
# Epoch 5/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 48s 7ms/step - accuracy: 0.7559 - loss: 0.6825 - val_accuracy: 0.7623 - val_loss: 0.6547 - learning_rate: 3.0000e-04
# Epoch 6/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 45s 6ms/step - accuracy: 0.7583 - loss: 0.6719 - val_accuracy: 0.7658 - val_loss: 0.6471 - learning_rate: 3.0000e-04
# Epoch 7/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 44s 6ms/step - accuracy: 0.7615 - loss: 0.6631 - val_accuracy: 0.7703 - val_loss: 0.6455 - learning_rate: 3.0000e-04
# Epoch 8/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 44s 6ms/step - accuracy: 0.7635 - loss: 0.6555 - val_accuracy: 0.7691 - val_loss: 0.6414 - learning_rate: 3.0000e-04
# Epoch 9/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 43s 6ms/step - accuracy: 0.7665 - loss: 0.6487 - val_accuracy: 0.7644 - val_loss: 0.6477 - learning_rate: 3.0000e-04
# Epoch 10/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7674 - loss: 0.6444 - val_accuracy: 0.7675 - val_loss: 0.6444 - learning_rate: 3.0000e-04
# Epoch 11/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 44s 6ms/step - accuracy: 0.7686 - loss: 0.6412 - val_accuracy: 0.7718 - val_loss: 0.6301 - learning_rate: 3.0000e-04
# Epoch 12/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 45s 6ms/step - accuracy: 0.7703 - loss: 0.6368 - val_accuracy: 0.7690 - val_loss: 0.6338 - learning_rate: 3.0000e-04
# Epoch 13/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 44s 6ms/step - accuracy: 0.7716 - loss: 0.6333 - val_accuracy: 0.7675 - val_loss: 0.6385 - learning_rate: 3.0000e-04
# Epoch 14/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7714 - loss: 0.6310 - val_accuracy: 0.7729 - val_loss: 0.6288 - learning_rate: 3.0000e-04
# Epoch 15/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 44s 6ms/step - accuracy: 0.7719 - loss: 0.6300 - val_accuracy: 0.7667 - val_loss: 0.6424 - learning_rate: 3.0000e-04
# Epoch 16/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 44s 6ms/step - accuracy: 0.7731 - loss: 0.6278 - val_accuracy: 0.7696 - val_loss: 0.6355 - learning_rate: 3.0000e-04
# Epoch 17/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 45s 6ms/step - accuracy: 0.7737 - loss: 0.6254 - val_accuracy: 0.7744 - val_loss: 0.6270 - learning_rate: 3.0000e-04
# Epoch 18/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 45s 6ms/step - accuracy: 0.
50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 43s 6ms/step - accuracy: 0.7898 - loss: 0.5730 - val_accuracy: 0.7762 - val_loss: 0.6130 - learning_rate: 3.7500e-05
# Epoch 43/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7896 - loss: 0.5729 - val_accuracy: 0.7762 - val_loss: 0.6154 - learning_rate: 3.7500e-05
# Epoch 44/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 44s 6ms/step - accuracy: 0.7896 - loss: 0.5720 - val_accuracy: 0.7788 - val_loss: 0.6097 - learning_rate: 3.7500e-05
# Epoch 45/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 44s 6ms/step - accuracy: 0.7902 - loss: 0.5716 - val_accuracy: 0.7763 - val_loss: 0.6130 - learning_rate: 3.7500e-05
# Epoch 46/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 43s 6ms/step - accuracy: 0.7903 - loss: 0.5699 - val_accuracy: 0.7778 - val_loss: 0.6079 - learning_rate: 3.7500e-05
# Epoch 47/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7899 - loss: 0.5694 - val_accuracy: 0.7757 - val_loss: 0.6131 - learning_rate: 3.7500e-05
# Epoch 48/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 43s 6ms/step - accuracy: 0.7899 - loss: 0.5719 - val_accuracy: 0.7765 - val_loss: 0.6084 - learning_rate: 3.7500e-05
# Epoch 49/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 44s 6ms/step - accuracy: 0.7903 - loss: 0.5707 - val_accuracy: 0.7765 - val_loss: 0.6122 - learning_rate: 3.7500e-05
# Epoch 50/50
# 7002/7002 ━━━━━━━━━━━━━━━━━━━━ 45s 6ms/step - accuracy: 0.7917 - loss: 0.5674 - val_accuracy: 0.7761 - val_loss: 0.6128 - learning_rate: 1.8750e-05
# Accuracy = 0.7788, Kappa = 0.6981 -> Best model
#
# ===== FOLD 2/5 =====
# Epoch 1/50
# 6986/6986 ━━━━━━━━━━━━━━━━━━━━ 48s 6ms/step - accuracy: 0.6865 - loss: 0.8891 - val_accuracy: 0.7279 - val_loss: 0.7534 - learning_rate: 3.0000e-04
# Epoch 2/50
# 6986/6986 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7362 - loss: 0.7508 - val_accuracy: 0.7369 - val_loss: 0.7257 - learning_rate: 3.0000e-04
# Epoch 3/50
# 6986/6986 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7492 - loss: 0.7100 - val_accuracy: 0.7446 - val_loss: 0.7023 - learning_rate: 3.0000e-04
# Epoch 4/50
# 6986/6986 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7567 - loss: 0.6865 - val_accuracy: 0.7420 - val_loss: 0.7177 - learning_rate: 3.0000e-04
# Epoch 5/50
# 6986/6986 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7607 - loss: 0.6720 - val_accuracy: 0.7448 - val_loss: 0.7063 - learning_rate: 3.0000e-04
# Epoch 6/50
# 6986/6986 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7651 - loss: 0.6600 - val_accuracy: 0.7496 - val_loss: 0.6904 - learning_rate: 3.0000e-04
# Epoch 7/50
# 6986/6986 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7662 - loss: 0.6518 - val_accuracy: 0.7436 - val_loss: 0.6882 - learning_rate: 3.0000e-04
# Epoch 8/50
# 6986/6986 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7687 - loss: 0.6445 - val_accuracy: 0.7556 - val_loss: 0.6779 - learning_rate: 3.0000e-04
# Epoch 9/50
# 6986/6986 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7707 - loss: 0.6377 - val_accuracy: 0.7505 - val_loss: 0.6876 - learning_rate: 3.0000e-04
# Epoch 10/50
# 6986/6986 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7725 - loss: 0.6340 - val_accuracy: 0.7556 - val_loss: 0.6717 - learning_rate: 3.0000e-04
# Epoch 11/50
# 6986/6986 ━━━━━━━━━━━━━━━━━━━━ 43s 6ms/step - accuracy: 0.7733 - loss: 0.6302 - val_accuracy: 0.7515 - val_loss: 0.6830 - learning_rate: 3.0000e-04
# Epoch 12/50
# 6986/6986 ━━━━━━━━━━━━━━━━━━━━ 43s 6ms/step - accuracy: 0.7749 - loss: 0.6257 - val_accuracy: 0.7581 - val_loss: 0.6681 - learning_rate: 3.0000e-04
# Epoch 13/50
# 6986/6986 ━━━━━━━━━━━━━━━━━━━━ 43s 6ms/step - accuracy: 0.7754 - loss: 0.6243 - val_accuracy: 0.7577 - val_loss: 0.6716 - learning_rate: 3.0000e-04
# Epoch 14/50
# 6986/6986 ━━━━━━━━━━━━━━━━━━━━ 44s 6ms/step - accuracy: 0.7758 - loss: 0.6224 - val_accuracy: 0.7540 - val_loss: 0.6709 - learning_rate: 3.0000e-04
# Epoch 15/50
# 6986/6986 ━━━━━━━━━━━━━━━━━━━━ 44s 6ms/step - accuracy: 0.
50
# 7019/7019 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7869 - loss: 0.5849 - val_accuracy: 0.7512 - val_loss: 0.7042 - learning_rate: 1.5000e-04
# Epoch 26/50
# 7019/7019 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7874 - loss: 0.5827 - val_accuracy: 0.7490 - val_loss: 0.7179 - learning_rate: 1.5000e-04
# Epoch 27/50
# 7019/7019 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7887 - loss: 0.5768 - val_accuracy: 0.7508 - val_loss: 0.7029 - learning_rate: 7.5000e-05
# Epoch 28/50
# 7019/7019 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7896 - loss: 0.5745 - val_accuracy: 0.7473 - val_loss: 0.7135 - learning_rate: 7.5000e-05
# Epoch 29/50
# 7019/7019 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7900 - loss: 0.5733 - val_accuracy: 0.7454 - val_loss: 0.7201 - learning_rate: 7.5000e-05
# Epoch 30/50
# 7019/7019 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7908 - loss: 0.5714 - val_accuracy: 0.7502 - val_loss: 0.7038 - learning_rate: 7.5000e-05
# Epoch 31/50
# 7019/7019 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7905 - loss: 0.5722 - val_accuracy: 0.7511 - val_loss: 0.7025 - learning_rate: 7.5000e-05
# Epoch 32/50
# 7019/7019 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7925 - loss: 0.5672 - val_accuracy: 0.7513 - val_loss: 0.7007 - learning_rate: 3.7500e-05
# Epoch 33/50
# 7019/7019 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7924 - loss: 0.5655 - val_accuracy: 0.7485 - val_loss: 0.7005 - learning_rate: 3.7500e-05
# Epoch 34/50
# 7019/7019 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7923 - loss: 0.5648 - val_accuracy: 0.7505 - val_loss: 0.7020 - learning_rate: 3.7500e-05
# Epoch 35/50
# 7019/7019 ━━━━━━━━━━━━━━━━━━━━ 44s 6ms/step - accuracy: 0.7930 - loss: 0.5640 - val_accuracy: 0.7495 - val_loss: 0.7053 - learning_rate: 3.7500e-05
# Epoch 36/50
# 7019/7019 ━━━━━━━━━━━━━━━━━━━━ 46s 7ms/step - accuracy: 0.7932 - loss: 0.5651 - val_accuracy: 0.7483 - val_loss: 0.7026 - learning_rate: 3.7500e-05
# Accuracy = 0.7568, Kappa = 0.6699
#
# ===== FOLD 5/5 =====
# Epoch 1/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 50s 6ms/step - accuracy: 0.6883 - loss: 0.8892 - val_accuracy: 0.7463 - val_loss: 0.7079 - learning_rate: 3.0000e-04
# Epoch 2/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7321 - loss: 0.7607 - val_accuracy: 0.7522 - val_loss: 0.6804 - learning_rate: 3.0000e-04
# Epoch 3/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7456 - loss: 0.7212 - val_accuracy: 0.7666 - val_loss: 0.6503 - learning_rate: 3.0000e-04
# Epoch 4/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7512 - loss: 0.6983 - val_accuracy: 0.7663 - val_loss: 0.6444 - learning_rate: 3.0000e-04
# Epoch 5/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7564 - loss: 0.6823 - val_accuracy: 0.7676 - val_loss: 0.6364 - learning_rate: 3.0000e-04
# Epoch 6/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7590 - loss: 0.6711 - val_accuracy: 0.7628 - val_loss: 0.6456 - learning_rate: 3.0000e-04
# Epoch 7/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7625 - loss: 0.6597 - val_accuracy: 0.7652 - val_loss: 0.6336 - learning_rate: 3.0000e-04
# Epoch 8/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7635 - loss: 0.6547 - val_accuracy: 0.7676 - val_loss: 0.6268 - learning_rate: 3.0000e-04
# Epoch 9/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7670 - loss: 0.6479 - val_accuracy: 0.7743 - val_loss: 0.6205 - learning_rate: 3.0000e-04
# Epoch 10/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.7674 - loss: 0.6428 - val_accuracy: 0.7731 - val_loss: 0.6204 - learning_rate: 3.0000e-04
# Epoch 11/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7689 - loss: 0.6408 - val_accuracy: 0.7720 - val_loss: 0.6204 - learning_rate: 3.0000e-04
# Epoch 12/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.
50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7881 - loss: 0.5787 - val_accuracy: 0.7755 - val_loss: 0.6102 - learning_rate: 7.5000e-05
# Epoch 36/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7877 - loss: 0.5768 - val_accuracy: 0.7763 - val_loss: 0.6070 - learning_rate: 7.5000e-05
# Epoch 37/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7892 - loss: 0.5737 - val_accuracy: 0.7751 - val_loss: 0.6119 - learning_rate: 3.7500e-05
# Epoch 38/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7900 - loss: 0.5720 - val_accuracy: 0.7771 - val_loss: 0.6068 - learning_rate: 3.7500e-05
# Epoch 39/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7906 - loss: 0.5721 - val_accuracy: 0.7754 - val_loss: 0.6100 - learning_rate: 3.7500e-05
# Epoch 40/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7900 - loss: 0.5702 - val_accuracy: 0.7750 - val_loss: 0.6115 - learning_rate: 3.7500e-05
# Epoch 41/50
# 7029/7029 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.7904 - loss: 0.5713 - val_accuracy: 0.7698 - val_loss: 0.6187 - learning_rate: 3.7500e-05
# Accuracy = 0.7794, Kappa = 0.7018 -> Best model
#
#
# ===== FINAL RESULTS =====
# Mean ACC:   0.7664
# Mean KAPPA: 0.6823
# Best model saved at: ./models/best_resnet_feature.keras

# %% [markdown]
# ## 1D-CNN

# %%
def get_file_list_from_folders(*folders):
    file_list = []
    for folder in folders:
        for f in os.listdir(folder):
            if f.endswith(".npz"):
                file_list.append(os.path.join(folder, f))
    return np.array(file_list)

def create_generator(directory, is_training, batch_size):
    return utils.SleepDataGenerator(
        directory=directory,
        is_training=is_training,
        batch_size=batch_size,
        n_classes=5,
        use_context=True,
        window_size=3,
        use_lag_lead=True,
        downsample=True,
        target_length=1500,
        sampling_rate=50,
        lag_seconds=0.5
    )

def extract_subjects(file_list):
    subjects = []
    for f in file_list:
        fname = os.path.basename(f)
        digits = ''.join([c for c in fname if c.isdigit()])
        subjects.append(int(digits[:2]))   # primele 2 cifre = ID subiect
    return np.array(subjects)

def extract_labels(file_list):
    labels = []
    for f in file_list:
        data = np.load(f, allow_pickle=True)

        # y_raw este (n_epochs,)
        y_raw = data["y"] if "y" in data else data["arr_1"]

        # îl forțăm să fie vector 1D
        y_raw = np.array(y_raw).reshape(-1)

        # eticheta fișierului = cea mai frecventă etichetă
        label = int(np.bincount(y_raw).argmax())

        labels.append(label)

    return np.array(labels)

def build_medium_cnn(input_shape=(9000, 2)):
    model = Sequential([
        Input(shape=input_shape),
        Conv1D(32, 50, strides=4, activation='relu', padding='same'),
        MaxPooling1D(4),
        Conv1D(64, 15, strides=2, activation='relu', padding='same'),
        MaxPooling1D(4),
        Conv1D(128, 7, activation='relu', padding='same'),
        MaxPooling1D(2),
        Conv1D(256, 5, activation='relu', padding='same'),
        GlobalAveragePooling1D(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(5, activation='softmax')
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
train_path = "process_dataset/train"
val_path = "process_dataset/val"

file_list = get_file_list_from_folders(train_path, val_path)
labels = extract_labels(file_list)
subjects = extract_subjects(file_list)

results.append(kfold_cnn_generators_grouped(
    X_paths=file_list,
    y=labels,
    subjects=subjects,
    build_model_fn=build_medium_cnn,
    model_name="medium_cnn",
    model_type='DL-Raw',
    generator_fn=create_generator,
    callbacks_fn=utils.make_callbacks,
    batch_size=32,
    epochs=50,
    save_path="./models"
))
# Out:
# ===== FOLD 1/5 =====
# E0000 00:00:1779948656.130974  648648 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/50
# 245/245 ━━━━━━━━━━━━━━━━━━━━
50
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 199s 737ms/step - accuracy: 0.7674 - loss: 0.6233 - val_accuracy: 0.7504 - val_loss: 0.6537 - learning_rate: 2.5000e-04
# Epoch 49/50
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 199s 739ms/step - accuracy: 0.7731 - loss: 0.6138 - val_accuracy: 0.7425 - val_loss: 0.6690 - learning_rate: 2.5000e-04
# Epoch 50/50
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 203s 751ms/step - accuracy: 0.7568 - loss: 0.6355 - val_accuracy: 0.7419 - val_loss: 0.6639 - learning_rate: 2.5000e-04
# Accuracy = 0.7504, Kappa = 0.6617
#
#
# ===== FINAL RESULTS =====
# Mean ACC:   0.7527
# Mean KAPPA: 0.6646
# Best model saved at: ./models/best_medium_cnn.keras

# %% [markdown]
# ## SeqSleepNet

# %%
class Attention(layers.Layer):
    def __init__(self, units):
        super().__init__()
        self.W = layers.Dense(units)
        self.V = layers.Dense(1)

    def call(self, inputs):
        score = self.V(tf.nn.tanh(self.W(inputs)))
        weights = tf.nn.softmax(score, axis=1)
        context = tf.reduce_sum(weights * inputs, axis=1)
        return context
        
def build_seqsleepnet(input_length=4500, frame_length=50, frame_units=64, epoch_units=128):
    num_frames = input_length // frame_length

    inputs = layers.Input(shape=(input_length, 1))

    # reshape into frames
    x = layers.Reshape((num_frames, frame_length, 1))(inputs)

    # frame-level encoding
    x = layers.TimeDistributed(layers.Bidirectional(layers.GRU(frame_units, return_sequences=True)))(x)
    x = layers.TimeDistributed(layers.Bidirectional(layers.GRU(frame_units)))(x)

    # epoch-level encoding
    x = layers.Bidirectional(layers.GRU(epoch_units, return_sequences=True))(x)

    # attention
    x = utils.Attention(epoch_units)(x)

    # classifier
    x = layers.Dense(128, activation="relu")(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(5, activation="softmax")(x)

    return models.Model(inputs, outputs)

results.append(crossval_seqsleepnet(
    X_paths = file_list,y=labels,subjects=subjects,
    build_model_fn = lambda: build_seqsleepnet(),
    model_name = 'SeqSleepNet',model_type='Hybrid',
    generator_fn = lambda path, train, bs: utils.SleepDataGenerator(
        path,
        batch_size=bs,
        is_training=train,
        use_context=True,
        window_size=3,
        use_lag_lead=False,
        downsample=True,
        target_length=1500,
        sampling_rate=50,
        lag_seconds=0.5,
        select_channels=[0]
    ),batch_size = 32,
    epochs=50,
    save_path="./models",
))
# Out:
# ===== FOLD 1/5 =====
# Epoch 1/50

# %% [markdown]
# # Results

# %%
df_results = pd.DataFrame(results)

names = {
    'LGBM_calibrated': ['LGBM','LightGBM'],
    'XGB_calibrated': ['XGB','XGBoost'],
    'RF_calibrated': ['RF','Random Forest'],
    'LDA-Baseline':['LDA','Linear Discriminant Analysis'],
    'LogisticR-Baseline':['LR','Logistic Regression'],
    'lstm_se_focal': ['LSTM','Long-Short Term-Memory'],
    'resnet_feature': ['ResNet','Residual Neural Network'],
    'medium_cnn':['CNN','Convolution Neural Network'],
    'SeqSleepNet':['SSN','SeqSleepNet']
}

for i in names.keys():
    df_results.loc[df_results['name'] == i, 'full_name'] = names[i][1]
    df_results.loc[df_results['name'] == i, 'name'] = names[i][0]

df_results.to_csv("./model_results.csv", index=False)
